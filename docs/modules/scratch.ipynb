# %%
import sys

sys.path.append("../../")

# %%
# load secrets from a .env file using python-dotenv
from dotenv import load_dotenv
import os

load_dotenv("../.env")
MY_API_KEY = os.getenv("MY_API_KEY")
MY_API_URL = os.getenv("MY_API_URL")

# import krixik and initialize it with your personal secrets
from krixik import krixik

krixik.init(api_key=MY_API_KEY, api_url=MY_API_URL)

# %load_ext autoreload
# %autoreload 2
# Out:
# SUCCESS: You are now authenticated.

# %%
# reset pipelines for demo
def reset_pipeline(pipeline):
    current_files = pipeline.list(symbolic_directory_paths=["/*"])
    assert current_files["status_code"] != 500
    for item in current_files["items"]:
        delete_result = pipeline.delete(file_id=item["file_id"])
        assert delete_result["status_code"] != 500
    current_files = pipeline.list(symbolic_directory_paths=["/*"])
    assert current_files["status_code"] != 500
    assert len(current_files["items"]) == 0

# %% [markdown]
# This small function prints dictionaries very nicely in notebooks / markdown.

# %%
# print dictionaries / json nicely in notebooks / markdown
import json


def json_print(data):
    print(json.dumps(data, indent=2))

# %%
# import custom module creation tools
from krixik.pipeline_builder.module import Module
from krixik.pipeline_builder.pipeline import CreatePipeline

# instantiate module
module_1 = Module(module_type="json-to-txt")

# create custom pipeline object
custom = CreatePipeline(name="hi", module_chain=[])

# pass the custom object to the krixik operator (note you can also do this by passing its config)
pipeline = krixik.load_pipeline(pipeline=custom)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 13
#       9 custom = CreatePipeline(name='hi',
#      10                         module_chain=[])
#      12 # pass the custom object to the krixik operator (note you can also do this by passing its config)
# ---> 13 pipeline = krixik.load_pipeline(pipeline=custom)
#
# File ~/Desktop/krixik-cli/docs/modules/../../krixik/main.py:88, in krixik.load_pipeline(cls, config_path, pipeline)
#      85 init_data = cls.check_init_data()
#      87 # instantiate krixik server pipeline object
# ---> 88 pipeline_object = KrixikBasePipeline(
#      89     pipeline=custom_pipeline.name,
#      90     module_chain=custom_pipeline.module_chain,
#      91     output_process_keys=custom_pipeline.module_chain_output_process_keys,
#      92     api_key=init_data["api_key"],
#      93     api_url=init_data["api_url"],
#      94     api_check_val=init_data["api_check_val"]
#      95 )
#      97 pipeline_object.test_input = custom_pipeline.test_input
#      99 if custom_pipeline.module_chain[-1] == "vector-db":
#
# File ~/Desktop/krixik-cli/docs/modules/../../krixik/system_builder/base.py:43, in KrixikBasePipeline.__init__(self, pipeline, module_chain, output_process_keys, api_key, api_url, api_check_val)
#      41 self.__pipeline_ordered_modules = module_chain
#      42 self.__pipeline_output_process_keys = output_process_keys
# ---> 43 self.__first_module = self.__pipeline_ordered_modules[0]
#      44 self.__last_module = self.__pipeline_ordered_modules[-1]
#      46 self.__version = __version__
#
# IndexError: list index out of range

# %% [markdown]
# The `json-to-txt` module comes with a single model:
#
# - `base`: (default) joins a json of text snippets into a single text separated by double spaces
#
# These available modeling options and parameters are stored in our custom pipeline's configuration (described further in LINK HERE).  We can examine this configuration as shown below.

# %%
# nicely print the configuration of uor custom pipeline
json_print(custom.config)
# Out:
# {
#   "pipeline": {
#     "name": "json-to-txt-pipeline-1",
#     "modules": [
#       {
#         "name": "json-to-txt",
#         "models": [
#           {
#             "name": "base"
#           }
#         ],
#         "defaults": {
#           "model": "base"
#         },
#         "input": {
#           "type": "json",
#           "permitted_extensions": [
#             ".json"
#           ]
#         },
#         "output": {
#           "type": "text"
#         }
#       }
#     ]
#   }
# }

# %% [markdown]
# Here we can see the models and their associated parameters available for use.

# %%
# delete all processed datapoints belonging to this pipeline
reset_pipeline(pipeline)

# %% [markdown]
# ## using the `base` model

# %% [markdown]
# We first define a path to a local input file.

# %%
# define path to an input file from examples directory
test_file = "../../examples/input_data/1984_very_short.json"

# %% [markdown]
# Lets take a quick look at this file before processing.

# %%
# examine contents of input file
with open(test_file) as f:
    json_print(json.load(f))
# Out:
# [
#   {
#     "snippet": "It was a bright cold day in April, and the clocks were striking thirteen.",
#     "line_numbers": [
#       1
#     ]
#   },
#   {
#     "snippet": "Winston Smith, his chin nuzzled into his breast in an effort to escape the\nvile wind, slipped quickly through the glass doors of Victory Mansions,\nthough not quickly enough to prevent a swirl of gritty dust from entering\nalong with him.",
#     "line_numbers": [
#       2,
#       3,
#       4,
#       5
#     ]
#   }
# ]

# %% [markdown]
# Two sentences and their associated line numbers in the original text.
#
# Now let's process it using our `base` model.  Because `base` is the default model we need not input the optional `modules` argument into `.process`.

# %%
# define path to an input file from examples directory
test_file = "../../examples/input_data/1984_very_short.json"

# process for search
process_output = pipeline.process(
    local_file_path=test_file,
    local_save_directory=".",  # save output in current directory
    expire_time=60 * 5,  # set all process data to expire in 5 minutes
    wait_for_process=True,  # wait for process to complete before regaining ide
    verbose=False,
)  # set verbosity to False

# %% [markdown]
# The output of this process is printed below.  Because the output of this particular module-model pair is text, the process output is provided in this object is null.  However the file itself has been returned to the address noted in the `process_output_files` key.

# %%
# nicely print the output of this process
json_print(process_output)
# Out:
# {
#   "status_code": 200,
#   "pipeline": "json-to-txt-pipeline-1",
#   "request_id": "cdfb3448-b7d8-454d-bd83-7becfb1b85ab",
#   "file_id": "37d67bd1-08e8-484a-b7dc-8eaf7376bd93",
#   "message": "SUCCESS - output fetched for file_id 37d67bd1-08e8-484a-b7dc-8eaf7376bd93.Output saved to location(s) listed in process_output_files.",
#   "warnings": [],
#   "process_output": null,
#   "process_output_files": [
#     "./37d67bd1-08e8-484a-b7dc-8eaf7376bd93.txt"
#   ]
# }

# %% [markdown]
# We load in the text file output from `process_output_files` below.

# %%
# load in process output from file
import json

with open(process_output["process_output_files"][0], "r") as file:
    print(file.read())
# Out:
# It was a bright cold day in April, and the clocks were striking thirteen.
# Winston Smith, his chin nuzzled into his breast in an effort to escape the
# vile wind, slipped quickly through the glass doors of Victory Mansions,
# though not quickly enough to prevent a swirl of gritty dust from entering
# along with him.
