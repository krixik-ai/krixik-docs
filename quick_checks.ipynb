# %%
from utilities.converter import collect_mkdocks_toc
from utilities.link_check import check_file_links
from utilities.converter import convert_all_notebooks_remove

# %load_ext autoreload
# %autoreload 2

# %%
# convert all notebooks - removing those tagged with "remove_cell"
convert_all_notebooks_remove()

# %%
### check for dead links ###
# collect all entries from the mkdocs toc
all_toc = collect_mkdocks_toc()

# pick an example doc
for i in range(len(all_toc)):
    doc = all_toc[i]
    print(f"looking through doc {doc} for dead linkes...")

    # look for dead links in doc
    dead_links = check_file_links(doc, all_toc)
    print(f"dead links found: {dead_links}")
    print("=========")
    print("\n")
# Out:
# looking through doc index.md for dead linkes...
# dead links found: ['docs/examples/overview.md', 'docs/modules/overview.md', 'docs/system/overview.md']
# =========
#
#
# looking through doc system/system_overview.md for dead linkes...
# dead links found: ['docs/system/system/parameters_processing_files_through_pipelines/process_status_method.md']
# =========
#
#
# looking through doc system/initialization/install_cli.md for dead linkes...
# dead links found: []
# =========
#
#
# looking through doc system/initialization/initialize_and_authenticate.md for dead linkes...
# dead links found: []
# =========
#
#
# looking through doc system/pipeline_creation/create_pipeline.md for dead linkes...
# dead links found: ['docs/system/17-convenience_methods#view-all-available-modules-with-the-available_modules-property', 'docs/modules/modules/ai_model_modules/text-embedder_module.md', 'docs/system/modules/database_modules/vector-db_module.md']
# =========
#
#
# looking through doc system/pipeline_creation/pipeline_config.md for dead linkes...
# dead links found: []
# =========
#
#
# looking through doc system/pipeline_creation/saving_and_loading_pipelines.md for dead linkes...
# dead links found: ['#the-save_pipeline-method', 'docs/system/system/pipeline_creation/pipeline_config.md']
# =========
#
#
# looking through doc system/parameters_processing_files_through_pipelines/process_method.md for dead linkes...
# dead links found: ['#core-process-method-arguments', 'docs/system/examples/search_pipeline_examples/search_pipelines_overview.md']
# =========
#
#
# looking through doc system/parameters_processing_files_through_pipelines/JSON_input_format.md for dead linkes...
# dead links found: []
# =========
#
#
# looking through doc system/parameters_processing_files_through_pipelines/process_status_method.md for dead linkes...
# dead links found: ['docs/system/modules/ai_model_modules/text-embedder_module.md', 'docs/system/parameters_processing_files_through_pipelines/process_method.md#core-process-method-arguments', 'docs/system/parameters_processing_files_through_pipelines/process_method.md#core-process-method-arguments']
# =========
#
#
# looking through doc system/parameters_processing_files_through_pipelines/fetch_output_method.md for dead linkes...
# dead links found: []
# =========
#
#
# looking through doc system/file_system/list_method.md for dead linkes...
# dead links found: ['docs/system/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/system/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc system/file_system/update_method.md for dead linkes...
# dead links found: ['#observations-on-the-.update-Method', 'docs/system/parameters_processing_files_through_pipelines/process_method.md#core-process-method-arguments', 'docs/system/parameters_processing_files_through_pipelines/process_method.md#core-process-method-arguments', 'docs/system/parameters_processing_files_through_pipelines/process_method.md#core-process-method-arguments']
# =========
#
#
# looking through doc system/file_system/delete_method.md for dead linkes...
# dead links found: ['docs/system/system/parameters_processing_files_through_pipelines/process_method.md#core-process-method-arguments']
# =========
#
#
# looking through doc system/file_system/show_tree_method.md for dead linkes...
# dead links found: []
# =========
#
#
# looking through doc system/search_methods/semantic_search_method.md for dead linkes...
# dead links found: ['docs/system/system/search_methods/keyword_search_method.md', 'docs/system/modules/ai_model_modules/text-embedder_module.md', 'docs/system/modules/ai_model_modules/text-embedder_module.md', 'docs/system/modules/database_modules/vector-db_module.md', 'docs/system/system/file_system/list_method.md', 'docs/system/system/file_system/list_method.md#.list-method-arguments', 'docs/system/system/file_system/list_method.md', 'docs/system/system/file_system/list_method.md', 'docs/system/system/file_system/list_method.md', 'docs/system/modules/ai_model_modules/parser_module.md', 'docs/system/modules/modules/ai_model_modules/text-embedder_module.md', 'docs/system/modules/database_modules/vector-db_module.md', 'docs/system/examples/search_pipeline_examples/multi_basic_semantic_search.md', 'docs/system/system/pipeline_creation/create_pipeline.md', 'docs/system/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/system/system/file_system/list_method.md']
# =========
#
#
# looking through doc system/search_methods/keyword_search_method.md for dead linkes...
# dead links found: ['docs/system/system/search_methods/semantic_search_method.md', 'docs/system/modules/database_modules/keyword-db_module.md', 'docs/system/system/file_system/list_method.md', 'docs/system/system/file_system/list_method.md', 'docs/system/system/file_system/list_method.md', 'docs/system/system/file_system/list_method.md', 'docs/system/system/file_system/list_method.md', 'docs/system/modules/database_modules/keyword-db_module.md', 'docs/system/system/pipeline_creation/create_pipeline.md', 'docs/system/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/system/system/file_system/list_method.md', 'data/other_data/stop_words.txt']
# =========
#
#
# looking through doc system/convenience_methods/convenience_methods.md for dead linkes...
# dead links found: ["#view-a-pipeline's-module-chain-with-the-module_chain-property", "#view-a-pipeline's-module-chain-with-the-module_chain-property", 'docs/system/system/initialization/initialize_and_authenticate.md', 'docs/system/convenience_methods/..initialization/initialize_and_authenticate.md']
# =========
#
#
# looking through doc modules/modules_overview.md for dead linkes...
# dead links found: ['docs/modules/modules/ai_model_modules/ocr_module.md']
# =========
#
#
# looking through doc modules/ai_model_modules/caption_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-caption-Module', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_caption.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/ai_model_modules/ocr_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-ocr-Module', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_ocr.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/ai_model_modules/sentiment_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-sentiment-Module', 'docs/modules/system/parameters_processing_files_through_pipelines/JSON_input_format.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_sentiment.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/ai_model_modules/summarize_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-summarize-Module', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_summarize.md', 'docs/modules/examples/multi_module_non_search_pipeline_examples/multi_recursive_summarization.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/ai_model_modules/text-embedder_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-text-embedder-Module', 'docs/modules/system/parameters_processing_files_through_pipelines/JSON_input_format.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_text-embedder.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/ai_model_modules/parser_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-parser-Module', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_parser.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/ai_model_modules/transcribe_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-transcribe-Module', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_transcribe.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/ai_model_modules/translate_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-translate-Module', 'docs/modules/system/parameters_processing_files_through_pipelines/JSON_input_format.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_translate.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/database_modules/vector-db_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-vector-db-Module', '#a-single-module-pipeline-for-the-vector-db-module-and-local-querying', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_vector-db.md', 'docs/modules/database_modules/(https:/github.com/facebookresearch/faiss)', 'docs/modules/examples/single_module_pipelines/single_vector-db.md#querying-output-databases-locally', 'docs/modules/modules/ai_model_modules/text-embedder_module.md', 'docs/modules/system/search_methods/semantic_search_method.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/database_modules/keyword-db_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-keyword-db-Module', '#a-single-module-pipeline-for-the-keyword-db-module-and-local-querying', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_keyword-db.md', 'docs/modules/examples/single_module_pipelines/single_keyword-db.md#querying-output-databases-locally', 'docs/modules/system/search_methods/keyword_search_method.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc modules/support_function_modules/json-to-txt_module.md for dead linkes...
# dead links found: ['#model-parameters-in-the-json-to-txt-Module', 'docs/modules/system/parameters_processing_files_through_pipelines/JSON_input_format.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/modules/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/modules/examples/single_module_pipelines/single_json-to-txt.md', 'docs/modules/system/convenience_methods/convenience_methods.md', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-input-and-output-examples', 'docs/modules/system/convenience_methods/convenience_methods.md#view-module-click-data-with-the-.click_data-method']
# =========
#
#
# looking through doc examples/pipeline_examples_overview.md for dead linkes...
# dead links found: []
# =========
#
#
# looking through doc examples/single_module_pipelines/single_caption.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/caption_module.md', 'docs/examples/modules/ai_model_modules/caption_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/caption_module.md', 'docs/examples/modules/ai_model_modules/caption_module.md', 'docs/examples/modules/ai_model_modules/caption_module.md#inputs-and-outputs-of-the-caption-module', 'docs/examples/modules/ai_model_modules/caption_module.md', 'docs/examples/modules/ai_model_modules/caption_module.md#available-models-in-the-caption-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/caption_module.md#available-models-in-the-caption-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_ocr.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/ocr_module.md', 'docs/examples/modules/ai_model_modules/ocr_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/ocr_module.md', 'docs/examples/modules/ai_model_modules/ocr_module.md', 'docs/examples/modules/ai_model_modules/ocr_module.md#inputs-and-outputs-of-the-ocr-module', 'docs/examples/modules/ai_model_modules/ocr_module.md', 'docs/examples/modules/ai_model_modules/ocr_module.md#available-models-in-the-ocr-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/ocr_module.md#available-models-in-the-ocr-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_sentiment.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/JSON_input_format.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md#available-models-in-the-sentiment-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md#available-models-in-the-sentiment-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_summarize.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/modules/ai_model_modules/summarize_module.md#available-models-in-the-summarize-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/summarize_module.md#available-models-in-the-summarize-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/examples/multi_module_non_search_pipeline_examples/multi_recursive_summarization.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_text-embedder.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/JSON_input_format.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md#available-models-in-the-text-embedder-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md#available-models-in-the-text-embedder-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_parser.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md#available-models-in-the-parser-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/parser_module.md#available-models-in-the-parser-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_transcribe.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md#available-models-in-the-transcribe-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md#available-models-in-the-transcribe-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_translate.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/JSON_input_format.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md#available-models-in-the-translate-module', 'docs/examples/https:/huggingface.co/Helsinki-NLP/opus-mt-en-es', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/translate_module.md#available-models-in-the-translate-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_keyword-db.md for dead linkes...
# dead links found: ['docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/modules/database_modules/keyword-db_module.md#available-models-in-the-keyword-db-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/system/search_methods/keyword_search_method.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_vector-db.md for dead linkes...
# dead links found: ['#using-the-semantic_search-method', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/examples/search_pipeline_examples/multi_basic_semantic_search.md', 'docs/examples/examples/search_pipeline_examples/multi_snippet_semantic_search.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/modules/database_modules/vector-db_module.md#available-models-in-the-vector-db-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/examples/search_pipeline_examples/multi_basic_semantic_search.md', 'docs/examples/examples/search_pipeline_examples/multi_snippet_semantic_search.md', 'docs/examples/system/search_methods/semantic_search_method.md']
# =========
#
#
# looking through doc examples/single_module_pipelines/single_json-to-txt.md for dead linkes...
# dead links found: ['docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/JSON_input_format.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md#available-models-in-the-json-to-txt-module', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/multi_module_non_search_pipeline_examples/multi_recursive_summarization.md for dead linkes...
# dead links found: ['docs/examples/examples/single_module_pipelines/single_summarize.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/modules/ai_model_modules/summarize_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/multi_module_non_search_pipeline_examples/multi_translated_transcription.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/multi_module_non_search_pipeline_examples/multi_sentiment_analysis_on_transcription.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/multi_module_non_search_pipeline_examples/multi_sentiment_analysis_on_translation.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/multi_module_non_search_pipeline_examples/multi_sentiment_analysis_on_translated_transcription.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/sentiment_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md#available-models-in-the-transcribe-module', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/search_pipelines_overview.md for dead linkes...
# dead links found: ['docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/examples/search_pipeline_examples/multi_basic_semantic_search.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/examples/search_pipeline_examples/multi_basic_keyword-search.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/examples/search_pipeline_examples/multi_semantically_searchable_transcription.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/examples/search_pipeline_examples/multi_keyword_searchable_transcription.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/examples/search_pipeline_examples/multi_semantically_searchable_translation.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/examples/search_pipeline_examples/multi_semantically_searchable_translated_transcription.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/examples/search_pipeline_examples/multi_semantically_searchable_ocr.md', 'docs/examples/modules/ai_model_modules/ocr_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/examples/search_pipeline_examples/multi_keyword_searchable_image_captions.md', 'docs/examples/modules/ai_model_modules/caption_module.md', 'docs/examples/system/search_methods/keyword_search_method.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/multi_basic_semantic_search.md for dead linkes...
# dead links found: ['docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/search_methods/semantic_search_method.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/multi_snippet_semantic_search.md for dead linkes...
# dead links found: ['docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/JSON_input_format.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/search_methods/semantic_search_method.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/multi_basic_keyword-search.md for dead linkes...
# dead links found: ['docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/examples/single_module_pipelines/single_keyword-db.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/multi_semantically_searchable_transcription.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/search_methods/semantic_search_method.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/multi_keyword_searchable_transcription.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/system/search_methods/keyword_search_method.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/multi_semantically_searchable_translation.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/search_methods/semantic_search_method.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/multi_semantically_searchable_translated_transcription.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/transcribe_module.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/modules/ai_model_modules/translate_module.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/search_methods/semantic_search_method.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/multi_semantically_searchable_ocr.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/ocr_module.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/ocr_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/ai_model_modules/parser_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/system/search_methods/semantic_search_method.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/ai_model_modules/text-embedder_module.md', 'docs/examples/modules/database_modules/vector-db_module.md', 'docs/examples/system/search_methods/semantic_search_method.md']
# =========
#
#
# looking through doc examples/search_pipeline_examples/multi_keyword_searchable_image_captions.md for dead linkes...
# dead links found: ['docs/examples/modules/ai_model_modules/caption_module.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/(../modules/ai_model_modules/caption_module.md)', 'docs/examples/modules/support_function_modules/json-to-txt_module.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/system/pipeline_creation/create_pipeline.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md#selecting-models-via-the-modules-argument', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/parameters_processing_files_through_pipelines/process_method.md', 'docs/examples/system/search_methods/keyword_search_method.md', 'docs/examples/modules/database_modules/keyword-db_module.md', 'docs/examples/system/search_methods/keyword_search_method.md']
# =========
#
#
# looking through doc future/future_of_krixik.md for dead linkes...
# dead links found: []
# =========
